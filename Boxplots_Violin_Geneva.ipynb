# %%
install.packages("viridis")
library("viridis")
install.packages("missMDA")
library("missMDA")
install.packages("factoextra")
library("factoextra")
install.packages("MASS")
library("MASS")
install.packages("ggplot2")
library("ggplot2")
install.packages("ggfortify")
library("ggfortify")
install.packages("cowplot")
library("cowplot")
# Out:
# package 'viridis' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\daeda\AppData\Local\Temp\RtmpEXe8Qd\downloaded_packages
# Loading required package: viridisLite
# package 'missMDA' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\daeda\AppData\Local\Temp\RtmpEXe8Qd\downloaded_packages
# package 'factoextra' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\daeda\AppData\Local\Temp\RtmpEXe8Qd\downloaded_packages
# Loading required package: ggplot2
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
# package 'MASS' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'MASS'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# ...

# %%
Elements <- read.csv("allspec_shoot_xyz_concat.csv")

# %%
#violinplot(Elements$B11_X~Elements$spec_as_int) #Boron 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
boron <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = B11_X))+
  geom_violin(aes(y = B11_Y))+
  geom_violin(aes(y = B11_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Boron Concentration")+
  labs(title = expression(paste("B conc. among ", italic("Vitis "), "species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
boron
ggsave(filename = "Boron.jpg", plot = boron, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Na23_X~Elements$spec_as_int) #Sodium 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
sodium <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Na23_X))+
  geom_violin(aes(y = Na23_Y))+
  geom_violin(aes(y = Na23_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Sodium Concentration")+
  labs(title = expression(paste("Distribution of Sodium Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
sodium
ggsave(filename = "Sodium.jpg", plot = sodium, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Mg26_X~Elements$spec_as_int) #Magnesium 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
magnesium <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Mg26_X))+
  geom_violin(aes(y = Mg26_Y))+
  geom_violin(aes(y = Mg26_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Magnesium Concentration")+
  labs(title = expression(paste("Distribution of Magnesium Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
magnesium
ggsave(filename = "Magnesium.jpg", plot = magnesium, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Al27_X~Elements$spec_as_int) #Aluminium 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
aluminium <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Al27_X))+
  geom_violin(aes(y = Al27_Y))+
  geom_violin(aes(y = Al27_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Aluminium Concentration")+
  labs(title = expression(paste("Distribution of Aluminium Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
aluminium
ggsave(filename = "Aluminium.jpg", plot = aluminium, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$P31_X~Elements$spec_as_int) #Phosphorus 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
phosphorus <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = P31_X))+
  geom_violin(aes(y = P31_Y))+
  geom_violin(aes(y = P31_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Phosphorus Concentration")+
  labs(title = expression(paste("P conc. among ", italic("Vitis "), "species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
phosphorus
ggsave(filename = "Phosphorus.jpg", plot = phosphorus, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$S34_X~Elements$spec_as_int) #Sulfur 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
sulfur <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = S34_X))+
  geom_violin(aes(y = S34_Y))+
  geom_violin(aes(y = S34_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Sulfur Concentration")+
  labs(title = expression(paste("Distribution of Sulfur Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
sulfur
ggsave(filename = "Sulfur.jpg", plot = sulfur, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Warning message:
# "Removed 1 rows containing non-finite values (stat_ydensity)."
# Saving 6.67 x 6.67 in image
#
# Warning message:
# "Removed 1 rows containing non-finite values (stat_ydensity)."
# plot without title

# %%
#violinplot(Elements$K39_X~Elements$spec_as_int) #Potassium 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
potassium <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = K39_X))+
  geom_violin(aes(y = K39_Y))+
  geom_violin(aes(y = K39_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Potassium Concentration")+
  labs(title = expression(paste("Distribution of Potassium Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
potassium
ggsave(filename = "Potassium.jpg", plot = potassium, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Ca44_X~Elements$spec_as_int) #Calcium 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
calcium <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Ca44_X))+
  geom_violin(aes(y = Ca44_Y))+
  geom_violin(aes(y = Ca44_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Calcium Concentration")+
  labs(title = expression(paste("Ca conc. among ", italic("Vitis "), "species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
calcium
ggsave(filename = "Calcium.jpg", plot = calcium, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Fe54_X~Elements$spec_as_int) #Iron 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
iron <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Fe54_X))+
  geom_violin(aes(y = Fe54_Y))+
  geom_violin(aes(y = Fe54_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Iron Concentration")+
  labs(title = expression(paste("Distribution of Iron Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
iron
ggsave(filename = "Iron.jpg", plot = iron, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Mn55_X~Elements$spec_as_int) #Manganese 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
manganese <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Mn55_X))+
  geom_violin(aes(y = Mn55_Y))+
  geom_violin(aes(y = Mn55_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Manganese Concentration")+
  labs(title = expression(paste("Distribution of Manganese Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
manganese
ggsave(filename = "Manganese.jpg", plot = manganese, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Co59_X~Elements$spec_as_int) #Cobalt 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
cobalt <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Co59_X))+
  geom_violin(aes(y = Co59_Y))+
  geom_violin(aes(y = Co59_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Cobalt Concentration")+
  labs(title = expression(paste("Distribution of Cobalt Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
cobalt
ggsave(filename = "Cobalt.jpg", plot = cobalt, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Ni60_X~Elements$spec_as_int) #Nickel 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
nickel <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Ni60_X))+
  geom_violin(aes(y = Ni60_Y))+
  geom_violin(aes(y = Ni60_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Nickel Concentration")+
  labs(title = expression(paste("Distribution of Nickel Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
nickel
ggsave(filename = "Nickel.jpg", plot = nickel, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Cu63_X~Elements$spec_as_int) #Copper 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
copper <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Cu63_X))+
  geom_violin(aes(y = Cu63_Y))+
  geom_violin(aes(y = Cu63_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Copper Concentration")+
  labs(title = expression(paste("Distribution of Copper Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
copper
ggsave(filename = "Copper.jpg", plot = copper, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Zn66_X~Elements$spec_as_int) #Zinc 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
zinc <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Zn66_X))+
  geom_violin(aes(y = Zn66_Y))+
  geom_violin(aes(y = Zn66_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Zinc Concentration")+
  labs(title = expression(paste("Distribution of Zinc Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
zinc
ggsave(filename = "Zinc.jpg", plot = zinc, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$As75_X~Elements$spec_as_int) #Arsenic 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
arsenic <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = As75_X))+
  geom_violin(aes(y = As75_Y))+
  geom_violin(aes(y = As75_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Arsenic Concentration")+
  labs(title = expression(paste("As conc. among ", italic("Vitis "), "species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
arsenic
ggsave(filename = "Arsenic.jpg", plot = arsenic, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Warning message:
# "Removed 4 rows containing non-finite values (stat_ydensity)."
# Saving 6.67 x 6.67 in image
#
# Warning message:
# "Removed 4 rows containing non-finite values (stat_ydensity)."
# plot without title

# %%
#violinplot(Elements$Rb85_X~Elements$spec_as_int) #Rubiudium 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
rubiudium <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Rb85_X))+
  geom_violin(aes(y = Rb85_Y))+
  geom_violin(aes(y = Rb85_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Rubiudium Concentration")+
  labs(title = expression(paste("Distribution of Rubiudium Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
rubiudium
ggsave(filename = "Rubiudium.jpg", plot = rubiudium, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Sr88_X~Elements$spec_as_int) #Strontium 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
strontium <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Sr88_X))+
  geom_violin(aes(y = Sr88_Y))+
  geom_violin(aes(y = Sr88_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Strontium Concentration")+
  labs(title = expression(paste("Distribution of Strontium Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
strontium
ggsave(filename = "Strontium.jpg", plot = strontium, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Mo98_X~Elements$spec_as_int) #Molybdenum 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
molybdenum <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Mo98_X))+
  geom_violin(aes(y = Mo98_Y))+
  geom_violin(aes(y = Mo98_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Molybdenum Concentration")+
  labs(title = expression(paste("Distribution of Molybdenum Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
molybdenum
ggsave(filename = "Molybdenum.jpg", plot = molybdenum, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
#violinplot(Elements$Cd111_X~Elements$spec_as_int) #Cadmium 
Elements$spec_as_int <- as.factor(Elements$spec_as_int)
cadmium <- ggplot(Elements, aes(x = spec_as_int, fill = spec_as_int, alpha = .5)) + 
  geom_violin(aes(y = Cd111_X))+
  geom_violin(aes(y = Cd111_Y))+
  geom_violin(aes(y = Cd111_Z))+
  scale_color_viridis_d(aesthetics = "fill")+
  theme_bw()+
  xlab("Species")+
  ylab("Z-Score of Cadmium Concentration")+
  labs(title = expression(paste("Distribution of Cadmium Concentration among ", italic("Vitis "), "Species")))+ 
  guides(alpha = FALSE)+
  theme(plot.title = element_text(hjust = .55), legend.text = element_text(face = "italic"))+
  scale_fill_discrete(name = "Species", labels = c("V. acerifolia", "V. aestivalis", "V. cinera", "V. labrusca", "V. palmatta", "V. riparia","V. rupestris", "V. vulpina"))                
cadmium
ggsave(filename = "Cadmium.jpg", plot = cadmium, dpi = "retina")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
#
# Saving 6.67 x 6.67 in image
# plot without title

# %%
p <- plot_grid(phosphorus, calcium, boron, arsenic)
p <- p + labs(caption = expression(paste(bold("Figure 2: "), "Lorem ipsum dolor est")))
p <- p + theme(plot.caption = element_text(hjust = 0))
p
ggsave(filename = "Grid Plot.jpg", dpi = "retina")
# Out:
# Warning message:
# "Removed 4 rows containing non-finite values (stat_ydensity)."
# Saving 6.67 x 6.67 in image
# plot without title
