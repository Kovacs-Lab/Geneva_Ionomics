# %%
data <- read.csv("spec_shoot_xyz_combined_edited.csv")

# %%
acerifolia <- subset(data, species=="acerifolia")
aestivalis <- subset(data, species=="aestivalis")
cinerea <- subset(data, species=="cinerea")
labrusca <- subset(data, species=="labrusca")
palmata <- subset(data, species=="palmata")
riparia <- subset(data, species=="riparia")
rupestris <- subset(data, species=="rupestris")
vulpina <- subset(data, species=="vulpina")
acerifolia_aestivalis <- subset(data, species =="acerifolia" | species=="aestivalis")
acerifolia_cinerea <- subset(data, species =="acerifolia" | species=="cinerea")
acerifolia_labrusca <- subset(data, species =="acerifolia" | species=="labrusca")
acerifolia_palmata <- subset(data, species =="acerifolia" | species=="palmata")
acerifolia_riparia <- subset(data,species =="acerifolia" | species=="riparia")
acerifolia_rupestris <- subset(data,species =="acerifolia" | species=="rupestris")
acerifolia_vulpina <- subset(data,species =="acerifolia" | species=="vulpina")
aestivalis_cinerea <- subset(data, species =="aestivalis" | species=="cinerea")
aestivalis_labrusca <- subset(data, species =="aestivalis" | species=="labrusca")
aestivalis_palmata <- subset(data, species =="aestivalis" | species=="palmata")
aestivalis_riparia <- subset(data, species =="aestivalis" | species=="riparia")
aestivalis_rupestris <- subset(data, species =="aestivalis" | species=="rupestris")
aestivalis_vulpina <- subset(data, species =="aestivalis" | species=="vulpina")
cinerea_labrusca <- subset(data, species=="cinerea" | species=="labrusca")
cinerea_palmata <- subset(data, species=="cinerea" | species=="palmata")
cinerea_riparia  <- subset(data, species=="cinerea" | species=="riparia")
cinerea_rupestris <- subset(data, species=="cinerea" | species=="rupestris")
cinerea_vulpina <- subset(data, species=="cinerea" | species=="vulpina")
labrusca_palmata <- subset(data, species=="labrusca" | species=="palmata")
labrusca_riparia <- subset(data, species=="labrusca" | species=="riparia")
labrusca_rupestris <- subset(data, species=="labrusca" | species=="rupestris")
labrusca_vulpina <- subset(data, species=="labrusca" | species=="vulpina")
palmata_riparia <- subset(data, species=="palmata" | species=="riparia")
palmata_rupestris <- subset(data, species=="palmata" | species=="rupestris")
palmata_vulpina <- subset(data, species=="palmata" | species=="vulpina")
riparia_rupestris <- subset(data, species=="riparia" | species=="rupestris")
riparia_vulpina <- subset(data, species=="riparia" | species=="vulpina")
rupestris_vulpina <- subset(data, species=="rupestris" | species=="vulpina")

# %%
formula <- as.formula(paste0("cbind(", paste(names(acerifolia)[5:23],collapse = ","),") ~LeafStage"))
formula2 <- as.formula(paste0("cbind(", paste(names(acerifolia)[5:23],collapse = ","),") ~LeafStage + species"))

# %%
summary(aov(formula, data = acerifolia))
# Out:
#  Response B11 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2  0.4258 0.21288  0.4112 0.6662
# Residuals   33 17.0835 0.51768
#
#  Response Na23 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 4.9510 2.47551  14.666 2.772e-05 ***
# Residuals   33 5.5702 0.16879
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 26.814 13.4067  35.119 6.717e-09 ***
# Residuals   33 12.598  0.3818
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 17.603  8.8014  20.286 1.798e-06 ***
# Residuals   33 14.318  0.4339
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response P31 :
#             Df  Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2  8.3051  4.1526  6.5177 0.004116 **
# Residuals   33 21.0251  0.6371
# ---
# ...

# %%
summary(aov(formula, data = aestivalis))
# Out:
#  Response B11 :
#             Df Sum Sq  Mean Sq F value Pr(>F)
# LeafStage    2 0.1268 0.063424  0.2148 0.8091
# Residuals   15 4.4289 0.295262
#
#  Response Na23 :
#             Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2 6.4067  3.2034  5.1837 0.01944 *
# Residuals   15 9.2695  0.6180
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 5.1894 2.59472  13.733 0.0004077 ***
# Residuals   15 2.8341 0.18894
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2 4.7115 2.35574  7.2433 0.006288 **
# Residuals   15 4.8785 0.32523
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response P31 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 12.2030  6.1015  52.863 1.611e-07 ***
# Residuals   15  1.7313  0.1154
# ---
# ...

# %%
summary(aov(formula, data = cinerea))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2  3.589 1.79471  2.6533 0.07653 .
# Residuals   81 54.789 0.67641
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 69.938  34.969  38.137 2.133e-12 ***
# Residuals   81 74.271   0.917
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 33.892 16.9458  50.464 5.859e-15 ***
# Residuals   81 27.200  0.3358
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2   3.647  1.8234  1.3388 0.2679
# Residuals   81 110.314  1.3619
#
#  Response P31 :
#             Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2  3.683 1.84157  2.0459 0.1359
# Residuals   81 72.910 0.90013
#
#  Response S34 :
# ...

# %%
summary(aov(formula, data = labrusca))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value   Pr(>F)
# LeafStage     2 14.893  7.4464  13.128 7.18e-06 ***
# Residuals   117 66.362  0.5672
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 59.920 29.9600  47.276 8.955e-16 ***
# Residuals   117 74.146  0.6337
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 174.547  87.274  234.71 < 2.2e-16 ***
# Residuals   117  43.505   0.372
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 44.825 22.4124   45.07 3.071e-15 ***
# Residuals   117 58.181  0.4973
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response P31 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# ...

# %%
summary(aov(formula, data = palmata))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2 30.747 15.3732  12.094 0.001329 **
# Residuals   12 15.253  1.2711
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 20.4428 10.2214  64.752 3.719e-07 ***
# Residuals   12  1.8942  0.1579
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2 2.6094 1.30469  6.4281 0.01266 *
# Residuals   12 2.4356 0.20297
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2 0.6672 0.33361  0.5288 0.6024
# Residuals   12 7.5704 0.63087
#
#  Response P31 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2  2.0468 1.02339  1.2121 0.3315
# Residuals   12 10.1320 0.84434
#
#  Response S34 :
# ...

# %%
summary(aov(formula, data = riparia))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  26.44 13.2198  11.704 1.533e-05 ***
# Residuals   206 232.67  1.1295
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  54.419 27.2097  41.502 7.167e-16 ***
# Residuals   206 135.060  0.6556
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 70.849  35.424  131.25 < 2.2e-16 ***
# Residuals   206 55.598   0.270
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 53.863 26.9316  101.18 < 2.2e-16 ***
# Residuals   206 54.834  0.2662
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response P31 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# ...

# %%
summary(aov(formula, data = rupestris))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2  3.489  1.7445  2.1394 0.1253
# Residuals   71 57.893  0.8154
#
#  Response Na23 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 14.344  7.1719  18.836 2.738e-07 ***
# Residuals   71 27.033  0.3808
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 38.467 19.2337  59.044 7.908e-16 ***
# Residuals   71 23.128  0.3258
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2   0.631 0.31556  0.1173 0.8895
# Residuals   71 190.973 2.68976
#
#  Response P31 :
#             Df Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2 36.725 18.3627  32.389 1.01e-10 ***
# Residuals   71 40.253  0.5669
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response S34 :
# ...

# %%
summary(aov(formula, data = vulpina))
# Out:
#  Response B11 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2  0.0751 0.03757  0.0446 0.9564
# Residuals   30 25.2612 0.84204
#
#  Response Na23 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 5.3039 2.65193  10.178 0.0004226 ***
# Residuals   30 7.8163 0.26054
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 13.2686  6.6343  31.327 4.507e-08 ***
# Residuals   30  6.3533  0.2118
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2 5.5761 2.78807  18.082 7.04e-06 ***
# Residuals   30 4.6258 0.15419
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response P31 :
#             Df  Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2  3.0807 1.54036  3.0952 0.05997 .
# Residuals   30 14.9297 0.49766
# ---
# ...

# %%
summary(aov(formula2, data = acerifolia_aestivalis))
# Out:
#  Response B11 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2  0.5417 0.27083  0.6292 0.5372
# species      1  0.0537 0.05372  0.1248 0.7254
# Residuals   50 21.5233 0.43047
#
#  Response Na23 :
#             Df  Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2  5.4783 2.73916  6.6102 0.002837 **
# species      1  0.1351 0.13513  0.3261 0.570528
# Residuals   50 20.7192 0.41438
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 30.6634 15.3317 45.7074 5.151e-12 ***
# species      1  0.0035  0.0035  0.0103    0.9196
# Residuals   50 16.7716  0.3354
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 21.8859 10.9430 27.8806 7.347e-09 ***
# species      1  0.1551  0.1551  0.3952    0.5325
# Residuals   50 19.6247  0.3925
# ---
# ...

# %%
summary(aov(formula2, data = acerifolia_cinerea))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2  1.826 0.91322  1.4304 0.2434
# species       1  0.159 0.15878  0.2487 0.6189
# Residuals   116 74.061 0.63846
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  49.685 24.8425 27.4332 1.756e-10 ***
# species       1   5.638  5.6384  6.2264   0.01399 *
# Residuals   116 105.045  0.9056
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2 58.690 29.3451  81.412 < 2e-16 ***
# species       1  1.987  1.9868   5.512 0.02058 *
# Residuals   116 41.813  0.3605
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df  Sum Sq Mean Sq F value   Pr(>F)
# LeafStage     2  14.824  7.4118  6.5603 0.001999 **
# species       1   1.777  1.7766  1.5725 0.212362
# Residuals   116 131.057  1.1298
# ---
# ...

# %%
summary(aov(formula2, data = acerifolia_labrusca))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 11.795  5.8973 10.3070 6.344e-05 ***
# species       1  0.520  0.5197  0.9083    0.3421
# Residuals   152 86.969  0.5722
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 49.890 24.9452 40.0400 1.076e-14 ***
# species       1  1.747  1.7468  2.8038    0.0961 .
# Residuals   152 94.697  0.6230
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 197.640  98.820 251.081 < 2.2e-16 ***
# species       1  14.148  14.148  35.948 1.418e-08 ***
# Residuals   152  59.824   0.394
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2 62.157 31.0785 64.9164 <2e-16 ***
# ...

# %%
summary(aov(formula2, data = acerifolia_palmata))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2  9.675  4.8374  4.2233 0.02057 *
# species      1  1.841  1.8411  1.6074 0.21111
# Residuals   47 53.834  1.1454
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 11.6018  5.8009  12.826 3.588e-05 ***
# species      1  4.5613  4.5613  10.085  0.002639 **
# Residuals   47 21.2565  0.4523
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 27.2991 13.6496 37.3912 1.919e-10 ***
# species      1  0.2163  0.2163  0.5926    0.4453
# Residuals   47 17.1572  0.3650
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 14.8469  7.4234 13.7844 1.946e-05 ***
# ...

# %%
summary(aov(formula2, data = acerifolia_riparia))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value   Pr(>F)
# LeafStage     2  23.747 11.8737 11.3261 1.99e-05 ***
# species       1   7.315  7.3147  6.9773 0.008795 **
# Residuals   241 252.652  1.0483
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2  52.782 26.3912 43.2066 <2e-16 ***
# species       1   0.017  0.0167  0.0274 0.8686
# Residuals   241 147.206  0.6108
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq  F value Pr(>F)
# LeafStage     2 95.106  47.553 162.0831 <2e-16 ***
# species       1  0.279   0.279   0.9516 0.3303
# Residuals   241 70.706   0.293
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2 70.312  35.156 120.455 < 2e-16 ***
# ...

# %%
summary(aov(formula2, data = acerifolia_rupestris))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2  3.217  1.6083  2.2541 0.10998
# species       1  3.374  3.3739  4.7286 0.03189 *
# Residuals   106 75.632  0.7135
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df Sum Sq Mean Sq F value   Pr(>F)
# LeafStage     2 14.162  7.0810 19.8623 4.72e-08 ***
# species       1  0.885  0.8854  2.4834    0.118
# Residuals   106 37.789  0.3565
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2 64.741  32.371 94.4149 <2e-16 ***
# species       1  0.818   0.818  2.3848 0.1255
# Residuals   106 36.343   0.343
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2   9.118  4.5592  2.2539 0.1100
# species       1   1.687  1.6873  0.8342 0.3631
# ...

# %%
summary(aov(formula2, data = acerifolia_vulpina))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2  0.150 0.07476  0.1138 0.8926
# species      1  0.212 0.21231  0.3232 0.5716
# Residuals   65 42.696 0.65686
#
#  Response Na23 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2  5.7608 2.88042 10.4710 0.0001143 ***
# species      1  1.1157 1.11565  4.0557 0.0481666 *
# Residuals   65 17.8806 0.27509
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 38.818 19.4092 62.4090 7.477e-16 ***
# species      1  0.749  0.7494  2.4096    0.1255
# Residuals   65 20.215  0.3110
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 21.2909 10.6455 33.2165 1.153e-10 ***
# species      1  0.4204  0.4204  1.3118    0.2563
# Residuals   65 20.8317  0.3205
# ---
# ...

# %%
summary(aov(formula2, data = aestivalis_cinerea))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2  2.551 1.27525  2.0697 0.1317
# species      1  0.317 0.31723  0.5148 0.4748
# Residuals   98 60.384 0.61616
#
#  Response Na23 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 74.843  37.422 43.1237 3.676e-14 ***
# species      1  4.972   4.972  5.7293   0.01859 *
# Residuals   98 85.042   0.868
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2 38.866 19.4328 62.9567 < 2e-16 ***
# species      1  1.032  1.0317  3.3425 0.07055 .
# Residuals   98 30.250  0.3087
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2   6.805  3.4027  2.8564 0.06227 .
# species      1   2.132  2.1316  1.7894 0.18410
# Residuals   98 116.745  1.1913
# ---
# ...

# %%
summary(aov(formula2, data = aestivalis_labrusca))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 12.905  6.4523 11.8593 1.811e-05 ***
# species       1  0.651  0.6507  1.1961    0.2761
# Residuals   134 72.906  0.5441
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2 65.933  32.967 52.7091 < 2e-16 ***
# species       1  1.998   1.998  3.1943 0.07616 .
# Residuals   134 83.809   0.625
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 172.725  86.363 216.913 < 2.2e-16 ***
# species       1   7.622   7.622  19.143 2.419e-05 ***
# Residuals   134  53.351   0.398
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2 49.327 24.6634  52.236 <2e-16 ***
# ...

# %%
summary(aov(formula2, data = aestivalis_palmata))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2 13.888  6.9438  5.4917 0.009496 **
# species      1  1.916  1.9159  1.5152 0.228236
# Residuals   29 36.668  1.2644
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 23.9025 11.9513 24.5620 5.747e-07 ***
# species      1  4.7564  4.7564  9.7753     0.004 **
# Residuals   29 14.1107  0.4866
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 7.6248  3.8124 20.3094 3.057e-06 ***
# species      1 0.2092  0.2092  1.1145    0.2998
# Residuals   29 5.4437  0.1877
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2  4.1759 2.08794  4.4354 0.02086 *
# ...

# %%
summary(aov(formula2, data = aestivalis_riparia))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  24.609 12.3046 11.4851 1.789e-05 ***
# species       1   5.114  5.1137  4.7731   0.02995 *
# Residuals   223 238.912  1.0714
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2  59.393 29.6963 45.4485 <2e-16 ***
# species       1   0.287  0.2866  0.4386 0.5085
# Residuals   223 145.709  0.6534
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq  F value Pr(>F)
# LeafStage     2 75.855  37.927 144.3595 <2e-16 ***
# species       1  0.207   0.207   0.7872 0.3759
# Residuals   223 58.588   0.263
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq  F value Pr(>F)
# LeafStage     2 58.578 29.2891 109.3751 <2e-16 ***
# ...

# %%
summary(aov(formula2, data = aestivalis_rupestris))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2  3.076 1.53819  2.1545 0.12204
# species      1  2.809 2.80938  3.9350 0.05041 .
# Residuals   88 62.827 0.71394
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 19.932  9.9658 23.6106 6.184e-09 ***
# species      1  0.097  0.0973  0.2304    0.6324
# Residuals   88 37.144  0.4221
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2 43.210 21.6050 71.8844 <2e-16 ***
# species      1  0.405  0.4053  1.3485 0.2487
# Residuals   88 26.449  0.3006
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2   2.704  1.3520  0.5994 0.5514
# species      1   0.329  0.3286  0.1457 0.7036
# ...

# %%
summary(aov(formula2, data = aestivalis_vulpina))
# Out:
#  Response B11 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2  0.0243 0.01216  0.0191 0.9811
# species      1  0.3688 0.36884  0.5804 0.4500
# Residuals   47 29.8678 0.63549
#
#  Response Na23 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 11.2261  5.6130 15.0146 9.076e-06 ***
# species      1  0.2566  0.2566  0.6865    0.4116
# Residuals   47 17.5704  0.3738
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 18.3165  9.1583 46.1407 8.181e-12 ***
# species      1  0.5928  0.5928  2.9864   0.09053 .
# Residuals   47  9.3288  0.1985
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 9.9942  4.9971 23.9712 6.668e-08 ***
# species      1 0.0211  0.0211  0.1013    0.7517
# Residuals   47 9.7977  0.2085
# ---
# ...

# %%
summary(aov(formula2, data = cinerea_labrusca))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  14.627  7.3136 11.7012 1.564e-05 ***
# species       1   0.164  0.1640  0.2624     0.609
# Residuals   200 125.005  0.6250
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2 126.110  63.055 82.8765 < 2e-16 ***
# species       1   2.432   2.432  3.1969 0.07529 .
# Residuals   200 152.166   0.761
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 191.959  95.979 220.173 < 2.2e-16 ***
# species       1   9.307   9.307  21.349 6.851e-06 ***
# Residuals   200  87.186   0.436
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  40.085 20.0424 22.6619 1.346e-09 ***
# ...

# %%
summary(aov(formula2, data = cinerea_palmata))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2 12.375  6.1875  6.3890 0.002493 **
# species      1  1.451  1.4507  1.4979 0.224014
# Residuals   95 92.003  0.9685
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 88.535  44.268 53.9083 2.262e-16 ***
# species      1  0.428   0.428  0.5209    0.4722
# Residuals   95 78.011   0.821
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 35.603 17.8016 55.3866 < 2.2e-16 ***
# species      1  2.285  2.2851  7.1097  0.009012 **
# Residuals   95 30.533  0.3214
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2   3.713  1.8567  1.4887 0.2309
# species      1   0.097  0.0973  0.0780 0.7806
# ...

# %%
summary(aov(formula2, data = cinerea_riparia))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  20.754 10.3768 10.1179 5.661e-05 ***
# species       1   9.990  9.9896  9.7404  0.001985 **
# Residuals   289 296.393  1.0256
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 107.253  53.626  68.180 < 2.2e-16 ***
# species       1  11.835  11.835  15.047 0.0001299 ***
# Residuals   289 227.310   0.787
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 102.492  51.246 174.963 < 2.2e-16 ***
# species       1   8.503   8.503  29.031 1.479e-07 ***
# Residuals   289  84.647   0.293
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  51.710 25.8548  43.687 < 2.2e-16 ***
# ...

# %%
summary(aov(formula2, data = cinerea_rupestris))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2   3.536  1.7678  2.3436 0.09939 .
# species       1   3.407  3.4072  4.5171 0.03515 *
# Residuals   154 116.160  0.7543
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  73.634  36.817  50.339 < 2.2e-16 ***
# species       1  16.972  16.972  23.205 3.455e-06 ***
# Residuals   154 112.633   0.731
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq  F value Pr(>F)
# LeafStage     2 71.667  35.833 108.2910 <2e-16 ***
# species       1  0.370   0.370   1.1196 0.2917
# Residuals   154 50.959   0.331
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2   3.723  1.8615  0.9498 0.3891
# ...

# %%
summary(aov(formula2, data = cinerea_vulpina))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2  3.060 1.53024  2.1439 0.1219
# species       1  0.024 0.02376  0.0333 0.8556
# Residuals   113 80.654 0.71375
#
#  Response Na23 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 68.792  34.396  43.899 7.816e-15 ***
# species       1 12.542  12.542  16.007 0.0001131 ***
# Residuals   113 88.538   0.784
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 47.151 23.5756  79.376 < 2.2e-16 ***
# species       1  5.675  5.6749  19.107  2.76e-05 ***
# Residuals   113 33.562  0.2970
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df  Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2   7.502  3.7508  3.6331 0.02957 *
# species       1   4.215  4.2149  4.0827 0.04569 *
# Residuals   113 116.661  1.0324
# ---
# ...

# %%
summary(aov(formula2, data = labrusca_palmata))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 30.103 15.0515 20.2956 2.098e-08 ***
# species       1  1.045  1.0453  1.4096    0.2373
# Residuals   131 97.151  0.7416
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2 77.508  38.754 64.3484 < 2e-16 ***
# species       1  2.189   2.189  3.6348 0.05878 .
# Residuals   131 78.895   0.602
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 168.601  84.301 202.644 < 2.2e-16 ***
# species       1   9.809   9.809  23.579 3.358e-06 ***
# Residuals   131  54.496   0.416
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 42.196 21.0981  40.029 2.711e-14 ***
# ...

# %%
summary(aov(formula2, data = labrusca_riparia))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  38.427 19.2137  20.714 3.411e-09 ***
# species       1   9.478  9.4776  10.217  0.001528 **
# Residuals   325 301.463  0.9276
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2 109.096  54.548 82.4637 < 2e-16 ***
# species       1   3.813   3.813  5.7651 0.01691 *
# Residuals   325 214.980   0.661
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 212.316 106.158  264.06 < 2.2e-16 ***
# species       1  50.531  50.531  125.69 < 2.2e-16 ***
# Residuals   325 130.655   0.402
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  97.73  48.865  139.23 < 2.2e-16 ***
# ...

# %%
summary(aov(formula2, data = labrusca_rupestris))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  16.090  8.0448 12.0900 1.142e-05 ***
# species       1   2.622  2.6220  3.9403   0.04858 *
# Residuals   190 126.428  0.6654
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  71.073  35.536  64.406 < 2.2e-16 ***
# species       1   8.723   8.723  15.810 9.945e-05 ***
# Residuals   190 104.834   0.552
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 201.533 100.766 246.961 < 2.2e-16 ***
# species       1  13.091  13.091  32.083 5.398e-08 ***
# Residuals   190  77.525   0.408
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  32.877 16.4387 11.9324 1.313e-05 ***
# ...

# %%
summary(aov(formula2, data = labrusca_vulpina))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 12.324  6.1618  9.7395 0.0001059 ***
# species       1  0.017  0.0174  0.0275 0.8684291
# Residuals   149 94.267  0.6327
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 62.780 31.3898  55.411 < 2.2e-16 ***
# species       1  6.619  6.6192  11.684 0.0008129 ***
# Residuals   149 84.407  0.5665
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 179.254  89.627 228.588 < 2.2e-16 ***
# species       1  22.069  22.069  56.287 5.246e-12 ***
# Residuals   149  58.421   0.392
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2 48.465 24.2327 55.7699 < 2e-16 ***
# ...

# %%
summary(aov(formula2, data = palmata_riparia))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  39.156 19.5782  16.197 2.741e-07 ***
# species       1   0.077  0.0774   0.064    0.8005
# Residuals   220 265.933  1.2088
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2  68.476  34.238 52.4581 <2e-16 ***
# species       1   5.554   5.554  8.5093 0.0039 **
# Residuals   220 143.588   0.653
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq  F value Pr(>F)
# LeafStage     2 73.099  36.550 137.6766 <2e-16 ***
# species       1  0.033   0.033   0.1238 0.7253
# Residuals   220 58.404   0.265
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2 52.534 26.2668 89.6908 < 2e-16 ***
# ...

# %%
summary(aov(formula2, data = palmata_rupestris))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2 14.354  7.1771  6.5572 0.002247 **
# species      1  0.019  0.0186  0.0170 0.896577
# Residuals   85 93.036  1.0945
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#             Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 28.350 14.1752  33.858 1.532e-11 ***
# species      1  8.856  8.8562  21.153 1.466e-05 ***
# Residuals   85 35.586  0.4187
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2 39.905 19.9526 63.2876 < 2e-16 ***
# species      1  1.339  1.3385  4.2457 0.04241 *
# Residuals   85 26.798  0.3153
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage    2   0.867 0.43368  0.1853 0.8312
# species      1   2.440 2.43951  1.0421 0.3102
# ...

# %%
summary(aov(formula2, data = palmata_vulpina))
# Out:
#  Response B11 :
#             Df Sum Sq Mean Sq F value  Pr(>F)
# LeafStage    2 10.688  5.3438  3.8769 0.02813 *
# species      1  0.965  0.9653  0.7003 0.40720
# Residuals   44 60.649  1.3784
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2 19.6346  9.8173  27.300 1.953e-08 ***
# species      1  8.5566  8.5566  23.794 1.441e-05 ***
# Residuals   44 15.8226  0.3596
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#             Df  Sum Sq Mean Sq F value   Pr(>F)
# LeafStage    2 15.2018  7.6009 35.3342 7.05e-10 ***
# species      1  0.0445  0.0445  0.2069   0.6515
# Residuals   44  9.4650  0.2151
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#             Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage    2  5.6344 2.81720  9.6802 0.0003281 ***
# ...

# %%
summary(aov(formula2, data = riparia_rupestris))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  28.778 14.3892 13.7633 1.993e-06 ***
# species       1   0.686  0.6862  0.6564    0.4185
# Residuals   279 291.687  1.0455
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2  68.153  34.076 58.4635 < 2e-16 ***
# species       1   2.478   2.478  4.2513 0.04015 *
# Residuals   279 162.620   0.583
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 107.746  53.873 187.372 < 2.2e-16 ***
# species       1   4.338   4.338  15.089 0.0001282 ***
# Residuals   279  80.218   0.288
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  44.852 22.4262 24.4941 1.583e-10 ***
# ...

# %%
summary(aov(formula2, data = riparia_vulpina))
# Out:
#  Response B11 :
#              Df  Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2  22.930 11.4649 10.4403 4.506e-05 ***
# species       1   4.054  4.0540  3.6917   0.05588 .
# Residuals   238 261.356  1.0981
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Na23 :
#              Df  Sum Sq Mean Sq F value  Pr(>F)
# LeafStage     2  58.298 29.1492 48.1411 < 2e-16 ***
# species       1   2.225  2.2249  3.6746 0.05645 .
# Residuals   238 144.108  0.6055
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq  F value Pr(>F)
# LeafStage     2 83.460  41.730 158.4933 <2e-16 ***
# species       1  0.367   0.367   1.3922 0.2392
# Residuals   238 62.664   0.263
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df Sum Sq Mean Sq  F value Pr(>F)
# LeafStage     2 58.704 29.3522 116.0402 <2e-16 ***
# ...

# %%
summary(aov(formula2, data = rupestris_vulpina))
# Out:
#  Response B11 :
#              Df Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2  2.482 1.24091  1.5179 0.2240
# species       1  1.571 1.57097  1.9216 0.1687
# Residuals   103 84.206 0.81754
#
#  Response Na23 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 19.341  9.6705 28.3505 1.552e-10 ***
# species       1  0.098  0.0985  0.2886    0.5923
# Residuals   103 35.134  0.3411
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Mg26 :
#              Df Sum Sq Mean Sq F value    Pr(>F)
# LeafStage     2 51.597 25.7983  89.254 < 2.2e-16 ***
# species       1  3.516  3.5161  12.165 0.0007176 ***
# Residuals   103 29.772  0.2890
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Response Al27 :
#              Df  Sum Sq Mean Sq F value Pr(>F)
# LeafStage     2   3.565  1.7826  0.9261 0.3994
# species       1   0.263  0.2629  0.1366 0.7125
# Residuals   103 198.246  1.9247
#
#  Response P31 :
# ...
