# %%
install.packages("ggplot2")
library("ggplot2")
install.packages("ggpubr")
library("ggpubr")
install.packages("cowplot")
library("cowplot")
# Out:
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\daeda\AppData\Local\Temp\RtmpQ91Nl3\downloaded_packages
# Warning message:
# "package 'ggplot2' was built under R version 4.0.4"
# package 'ggpubr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\daeda\AppData\Local\Temp\RtmpQ91Nl3\downloaded_packages
# Warning message:
# "package 'ggpubr' was built under R version 4.0.4"
# package 'cowplot' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\daeda\AppData\Local\Temp\RtmpQ91Nl3\downloaded_packages
# Warning message:
# "package 'cowplot' was built under R version 4.0.4"
#
# Attaching package: 'cowplot'
#
#
# The following object is masked from 'package:ggpubr':
#
#     get_legend

# %%
x <- read.csv("gen_X_raw_ForRatios.csv")
y <- read.csv("gen_Y_raw_ForRatios.csv")
z <- read.csv("gen_Z_raw_ForRatios.csv")

# %%
acerifolia_x <- subset(x, species_position == "acerifolia_x")
aestivalis_x <- subset(x, species_position == "aestivalis_x")
cinerea_x <- subset(x, species_position == "cinerea_x")
labrusca_x <- subset(x, species_position == "labrusca_x")
palmata_x <- subset(x, species_position == "palmata_x")
riparia_x <- subset(x, species_position == "riparia_x")
rupestris_x <- subset(x, species_position == "rupestris_x")
vulpina_x <- subset(x, species_position == "vulpina_x")

# %%
acerifolia_y <- subset(y, species_position == "acerifolia_y")
aestivalis_y <- subset(y, species_position == "aestivalis_y")
cinerea_y <- subset(y, species_position == "cinerea_y")
labrusca_y <- subset(y, species_position == "labrusca_y")
palmata_y <- subset(y, species_position == "palmata_y")
riparia_y <- subset(y, species_position == "riparia_y")
rupestris_y <- subset(y, species_position == "rupestris_y")
vulpina_y <- subset(y, species_position == "vulpina_y")

# %%
acerifolia_z <- subset(z, species_position == "acerifolia_z")
aestivalis_z <- subset(z, species_position == "aestivalis_z")
cinerea_z <- subset(z, species_position == "cinerea_z")
labrusca_z <- subset(z, species_position == "labrusca_z")
palmata_z <- subset(z, species_position == "palmata_z")
riparia_z <- subset(z, species_position == "riparia_z")
rupestris_z <- subset(z, species_position == "rupestris_z")
vulpina_z <- subset(z, species_position == "vulpina_z")

# %%
acerifolia_xy <- acerifolia_x[3:21]/acerifolia_y[3:21]
aestivalis_xy <- aestivalis_x[3:21]/aestivalis_y[3:21]
cinerea_xy <- cinerea_x[3:21]/cinerea_y[3:21]
labrusca_xy <- labrusca_x[3:21]/labrusca_y[3:21]
palmata_xy <- palmata_x[3:21]/palmata_y[3:21]
riparia_xy <- riparia_x[3:21]/riparia_y[3:21]
rupestris_xy <- rupestris_x[3:21]/rupestris_y[3:21]
vulpina_xy <- vulpina_x[3:21]/vulpina_y[3:21]

# %%
acerifolia_xz <- acerifolia_x[3:21]/acerifolia_z[3:21]
aestivalis_xz <- aestivalis_x[3:21]/aestivalis_z[3:21]
cinerea_xz <- cinerea_x[3:21]/cinerea_z[3:21]
labrusca_xz <- labrusca_x[3:21]/labrusca_z[3:21]
palmata_xz <- palmata_x[3:21]/palmata_z[3:21]
riparia_xz <- riparia_x[3:21]/riparia_z[3:21]
rupestris_xz <- rupestris_x[3:21]/rupestris_z[3:21]
vulpina_xz <- vulpina_x[3:21]/vulpina_z[3:21]

# %%
acerifolia_yz <- acerifolia_y[3:21]/acerifolia_z[3:21]
aestivalis_yz <- aestivalis_y[3:21]/aestivalis_z[3:21]
cinerea_yz <- cinerea_y[3:21]/cinerea_z[3:21]
labrusca_yz <- labrusca_y[3:21]/labrusca_z[3:21]
palmata_yz <- palmata_y[3:21]/palmata_z[3:21]
riparia_yz <- riparia_y[3:21]/riparia_z[3:21]
rupestris_yz <- rupestris_y[3:21]/rupestris_z[3:21]
vulpina_yz <- vulpina_y[3:21]/vulpina_y[3:21]

# %%
acerifolia_xz_avg <- c(1:19)
acerifolia_xz_avg_grp <- c(1:19)
for (i in 1:19){
    acerifolia_xz_avg[i] <- mean(acerifolia_xz[,i]) - 1
    if (acerifolia_xz_avg[i] > 0){
        acerifolia_xz_avg_grp[i] = 1
    }
    else{
        acerifolia_xz_avg_grp[i] = 0
    }
}
acerifolia_xz_avg <- data.frame( ions = c(names(acerifolia_xz)), avg = acerifolia_xz_avg, grp = as.factor(acerifolia_xz_avg_grp))

# %%
aestivalis_xz_avg <- c(1:19)
aestivalis_xz_avg_grp <- c(1:19)
for (i in 1:19){
    aestivalis_xz_avg[i] <- mean(aestivalis_xz[,i]) - 1
    if (aestivalis_xz_avg[i] > 0){
        aestivalis_xz_avg_grp[i] = 1
    }
    else{
        aestivalis_xz_avg_grp[i] = 0
    }
}
aestivalis_xz_avg <- data.frame( ions = c(names(aestivalis_xz)), avg = aestivalis_xz_avg, grp = as.factor(aestivalis_xz_avg_grp))

# %%
cinerea_xz_avg <- c(1:19)
cinerea_xz_avg_grp <- c(1:19)
for (i in 1:19){
    cinerea_xz_avg[i] <- mean(cinerea_xz[,i]) - 1
    if (cinerea_xz_avg[i] > 0){
        cinerea_xz_avg_grp[i] = 1
    }
    else{
        cinerea_xz_avg_grp[i] = 0
    }
}
cinerea_xz_avg <- data.frame( ions = c(names(cinerea_xz)), avg = cinerea_xz_avg, grp = as.factor(cinerea_xz_avg_grp))

# %%
labrusca_xz_avg <- c(1:19)
labrusca_xz_avg_grp <- c(1:19)
for (i in 1:19){
    labrusca_xz_avg[i] <- mean(labrusca_xz[,i]) - 1
    if (labrusca_xz_avg[i] > 0){
        labrusca_xz_avg_grp[i] = 1
    }
    else{
        labrusca_xz_avg_grp[i] = 0
    }
}
labrusca_xz_avg <- data.frame( ions = c(names(labrusca_xz)), avg = labrusca_xz_avg, grp = as.factor(labrusca_xz_avg_grp))

# %%
palmata_xz_avg <- c(1:19)
palmata_xz_avg_grp <- c(1:19)
for (i in 1:19){
    palmata_xz_avg[i] <- mean(palmata_xz[,i]) - 1
    if (palmata_xz_avg[i] > 0){
        palmata_xz_avg_grp[i] = 1
    }
    else{
        palmata_xz_avg_grp[i] = 0
    }
}
palmata_xz_avg <- data.frame( ions = c(names(palmata_xz)), avg = palmata_xz_avg, grp = as.factor(palmata_xz_avg_grp))

# %%
riparia_xz_avg <- c(1:19)
riparia_xz_avg_grp <- c(1:19)
for (i in 1:19){
    riparia_xz_avg[i] <- mean(riparia_xz[,i]) - 1
    if (riparia_xz_avg[i] > 0){
        riparia_xz_avg_grp[i] = 1
    }
    else{
        riparia_xz_avg_grp[i] = 0
    }
}
riparia_xz_avg <- data.frame( ions = c(names(riparia_xz)), avg = riparia_xz_avg, grp = as.factor(riparia_xz_avg_grp))

# %%
rupestris_xz_avg <- c(1:19)
rupestris_xz_avg_grp <- c(1:19)
for (i in 1:19){
    rupestris_xz_avg[i] <- mean(rupestris_xz[,i]) - 1
    if (rupestris_xz_avg[i] > 0){
        rupestris_xz_avg_grp[i] = 1
    }
    else{
        rupestris_xz_avg_grp[i] = 0
    }
}
rupestris_xz_avg <- data.frame( ions = c(names(rupestris_xz)), avg = rupestris_xz_avg, grp = as.factor(rupestris_xz_avg_grp))

# %%
vulpina_xz_avg <- c(1:19)
vulpina_xz_avg_grp <- c(1:19)
for (i in 1:19){
    vulpina_xz_avg[i] <- mean(vulpina_xz[,i]) - 1
    if (vulpina_xz_avg[i] > 0){
        vulpina_xz_avg_grp[i] = 1
    }
    else{
        vulpina_xz_avg_grp[i] = 0
    }
}
vulpina_xz_avg <- data.frame( ions = c(names(vulpina_xz)), avg = vulpina_xz_avg, grp = as.factor(vulpina_xz_avg_grp))

# %%
a <- ggbarplot(acerifolia_xz_avg, y = "avg", x = "ions",
               sort.val = "desc",
               fill = "grp",
               sort.by.groups = FALSE,
               x.text.angle = 90)
a
# Out:
# plot without title

# %%
b <- ggbarplot(aestivalis_xz_avg, y = "avg", x = "ions",
               sort.val = "desc",
               fill = "grp",
               sort.by.groups = FALSE,
               x.text.angle = 90)
b
# Out:
# plot without title

# %%
c <- ggbarplot(cinerea_xz_avg, y = "avg", x = "ions",
               sort.val = "desc",
               fill = "grp",
               sort.by.groups = FALSE,
               x.text.angle = 90)
c
# Out:
# plot without title

# %%
d <- ggbarplot(labrusca_xz_avg, y = "avg", x = "ions",
               sort.val = "desc",
               fill = "grp",
               sort.by.groups = FALSE,
               x.text.angle = 90)
d
# Out:
# plot without title

# %%
e <- ggbarplot(palmata_xz_avg, y = "avg", x = "ions",
               sort.val = "desc",
               fill = "grp",
               sort.by.groups = FALSE,
               x.text.angle = 90)
e
# Out:
# plot without title

# %%
f <- ggbarplot(riparia_xz_avg, y = "avg", x = "ions",
               sort.val = "desc",
               fill = "grp",
               sort.by.groups = FALSE,
               x.text.angle = 90)
f
# Out:
# plot without title

# %%
g <- ggbarplot(rupestris_xz_avg, y = "avg", x = "ions",
               sort.val = "desc",
               fill = "grp",
               sort.by.groups = FALSE,
               x.text.angle = 90)
g
# Out:
# plot without title

# %%
h <- ggbarplot(vulpina_xz_avg, y = "avg", x = "ions",
               sort.val = "desc",
               fill = "grp",
               sort.by.groups = FALSE,
               x.text.angle = 90)
h
# Out:
# plot without title

# %%
p <- plot_grid(a,b,c,d)
q <- plot_grid(e,f,g,h)
p
q
# Out:
# plot without title
# plot without title

# %%
a <- ggbarplot(acerifolia_xy_avg, y = "avg", x = "ions",
               sort.val = "desc",
               fill = "grp",
               sort.by.groups = FALSE,
               x.text.angle = 90)
a
# Out:
# Error in ggbarplot(acerifolia_xy_avg, y = "avg", x = "ions", sort.val = "desc", : object 'acerifolia_xy_avg' not found
# Traceback:
#
# 1. ggbarplot(acerifolia_xy_avg, y = "avg", x = "ions", sort.val = "desc",
#  .     fill = "grp", sort.by.groups = FALSE, x.text.angle = 90)
